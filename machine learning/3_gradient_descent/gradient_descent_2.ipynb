# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('test_scores.csv')
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x = np.array(df.math)
x
# Out:
# array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67], dtype=int64)

# %%
y = np.array(df.cs)
y
# Out:
# array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73], dtype=int64)

# %%
# %matplotlib inline
def gradient_descent(x,y,iterations = 1000,learning_rate = 0.05):
    m_curr = b_curr = 0
    n = len(x)
    cost_previous = 0
    plt.scatter(x,y,color='red',marker='+',linewidth=5)
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
        plt.plot(x,y_predicted,color='green')
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        
        if i%50==1:
            print ("m {}, b {}, cost {}, iteration {}".format(m_curr,b_curr,cost, i))

# %%
gradient_descent(x,y,learning_rate = 0.00002)
# Out:
# m 0.358202304128, b 0.005063270368, cost 3427.1133014146017, iteration 1
# m 1.0445315191350018, b 0.014966150244077233, cost 31.811805693678874, iteration 51
# m 1.0445473615367813, b 0.015184533355568504, cost 31.811755529148417, iteration 101
# m 1.0445442846055086, b 0.01540262445806475, cost 31.811707955788048, iteration 151
# m 1.044541207505913, b 0.015620690520119652, cost 31.81166039334825, iteration 201
# m 1.0445381307595007, b 0.01583873155196603, cost 31.81161284182653, iteration 251
# m 1.0445350543662457, b 0.016056747556477128, cost 31.811565301220334, iteration 301
# m 1.0445319783261073, b 0.016274738536525647, cost 31.811517771527175, iteration 351
# m 1.0445289026390452, b 0.016492704494983947, cost 31.8114702527446, iteration 401
# m 1.0445258273050182, b 0.01671064543472416, cost 31.811422744870057, iteration 451
# m 1.0445227523239866, b 0.016928561358617922, cost 31.811375247901026, iteration 501
# m 1.0445196776959098, b 0.01714645226953663, cost 31.811327761835088, iteration 551
# m 1.044516603420747, b 0.017364318170351334, cost 31.811280286669643, iteration 601
# m 1.0445135294984575, b 0.017582159063932772, cost 31.811232822402232, iteration 651
# m 1.0445104559290013, b 0.017799974953151353, cost 31.811185369030326, iteration 701
# m 1.0445073827123377, b 0.01801776584087714, cost 31.811137926551453, iteration 751
# m 1.044504309848426, b 0.01823553172997986, cost 31.811090494963096, iteration 801
# m 1.044501237337226, b 0.01845327262332893, cost 31.811043074262773, iteration 851
# m 1.0444981651786969, b 0.018670988523793418, cost 31.810995664448008, iteration 901
# m 1.0444950933727986, b 0.018888679434242085, cost 31.81094826551625, iteration 951
